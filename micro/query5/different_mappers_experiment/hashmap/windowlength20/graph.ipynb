# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

d = pd.read_csv("combined.csv")
d2 = d[(d['SourcenumRecordsOutPerSecond_avg'] >= (d['rate'] * 0.95))]

plt.figure(figsize=(4,2))
plt.scatter(d2['nwindows'], d2['pkg_watts_avg'], c=d2['rate'], cmap='viridis')
plt.colorbar(label='Rate')
plt.xticks(d2.nwindows.unique())
plt.xlabel('Number of Windows')
plt.ylabel('Power (W)')
plt.title('Query5 HashMap WindowLength 20')
plt.ylim(bottom=0)
plt.xlim(left=0)
plt.grid()
plt.savefig("query5hashmapwindowlength20.pdf")

# %%
d2[(d2.rate==300000)][['nwindows', 'pkg_watts_avg']]
# Out:
#     nwindows  pkg_watts_avg
# 8          4          58.62
# 9          8          55.62
# 10        12          54.23
# 11        16          53.92
